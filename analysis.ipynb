# %%
import pandas as pd
import numpy as np
import os


def P(df, col):
    """
    Calculate the probability of each unique value in a column of a DataFrame and return a mapping the value to its probability.
    """
    # Calculate the probability of each unique value in the column
    prob = df[col].value_counts(normalize=True).to_dict()
    # Create a mapping of the value to its probability
    mapping = {k: v for k, v in prob.items()}
    return mapping

df = pd.read_csv(f'{os.getcwd()}/data/cleaned_data.csv')
df
# Out:
# C:\Users\fjo\AppData\Local\Temp\ipykernel_4828\2694552907.py:16: DtypeWarning: Columns (1,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'{os.getcwd()}/data/cleaned_data.csv')
#        ship_company train_operator container_type  dangerous_goods  custom  \
# 0           MAE-HAM            BOX            20G                0       0
# 1           MAE-HAM            BOX           40GH                0       0
# 2           MAE-HAM            BOX           40GH                0       0
# 3           MAE-HAM            BOX            20G                0       0
# 4           MAE-HAM            BOX           40GH                0       0
# ...             ...            ...            ...              ...     ...
# 276146          TFG            NaN           40GH                0       0
# 276147          TFG            NaN           40GH                0       0
# 276148          TFG            NaN           40GH                0       0
# 276149          TFG            NaN           40GH                0       0
# 276150          TFG            NaN           40GH                0       0
#
#         waste  full_empty content   weight   train_id  ... month_of_arrival  \
# 0           0           1     NaN   2826.0  BRV13837Z  ...          January
# 1           0           1     NaN   7331.0  BRV13837Z  ...          January
# 2           0           1     NaN   8815.0  BRV13837Z  ...          January
# 3           0           1     NaN  15492.0  BRV13837Z  ...          January
# 4           0           1     NaN   5778.0  BRV13837Z  ...          January
# ...       ...         ...     ...      ...        ...  ...              ...
# 276146      0           1     NaN   5510.0        NaN  ...         December
# 276147      0           1     NaN   8286.0        NaN  ...         December
# 276148      0           1     NaN   3802.0        NaN  ...         December
# 276149      0           1     NaN   5662.0        NaN  ...         December
# 276150      0           1     NaN   5179.0        NaN  ...         December
#
#        container_owner_prefix equipment_identifier weather_today  \
# 0                         HAS                    U         Regen
# 1                         MSK                    U         Regen
# 2                         GES                    U         Regen
# 3                         HAS                    U         Regen
# 4                         MRK                    U         Regen
# ...                       ...                  ...           ...
# 276146                    ONE                    U         Regen
# 276147                    SEL                    U         Regen
# 276148                    FFA                    U         Regen
# 276149                    HAM                    U         Regen
# 276150                    TCN                    U         Regen
#
#         weather_prev_day weather_next_day_1  weather_next_day_2  \
# 0                 Niesel           Unwetter              Niesel
# 1                 Niesel           Unwetter              Niesel
# 2                 Niesel           Unwetter              Niesel
# 3                 Niesel           Unwetter              Niesel
# 4                 Niesel           Unwetter              Niesel
# ...                  ...                ...                 ...
# 276146             Regen           Unwetter               Regen
# 276147             Regen           Unwetter               Regen
# 276148             Regen           Unwetter               Regen
# 276149             Regen           Unwetter               Regen
# 276150             Regen           Unwetter               Regen
#
#         weather_next_day_3  weather_next_day_4  weather_next_day_5
# 0                   Schnee              Schnee              Schnee
# 1                   Schnee              Schnee              Schnee
# 2                   Schnee              Schnee              Schnee
# 3                   Schnee              Schnee              Schnee
# 4                   Schnee              Schnee              Schnee
# ...                    ...                 ...                 ...
# 276146               Regen               Regen               Regen
# 276147               Regen               Regen               Regen
# 276148               Regen               Regen               Regen
# 276149               Regen               Regen               Regen
# 276150               Regen               Regen               Regen
#
# [276151 rows x 35 columns]

# %% [markdown]
# # Container Parameter Distributions

# %%
unittypes = pd.read_csv(f'{os.getcwd()}/data/unittype.csv')

# Create a new column 'unit_type' in df and do a join of container type onto unittype and return category
df['unit_type'] = df['container_type'].map(unittypes.set_index('Unittype')['Category'])
df['unit_type'] = df['unit_type'].fillna('Unknown')
df['unit_type'] = df['unit_type'].replace('', 'Unknown')

df['unit_type'].value_counts()
print(P(df, 'unit_type'))
# Out:
# {"40' Container": 0.516474682329595, 'Wechselbrücke': 0.2485524224065819, "20' Container": 0.17511071841130396, 'Trailer': 0.031486396935010194, "30' Container": 0.017827203233013823, "45' Container": 0.010544955477257008, 'Unknown': 3.6212072380690276e-06}

# %%
# remove all entries where the container type does not start with '20' or '40'
df = df[df['unit_type'].str.startswith(('20', '40', 'Wechselbrücke', 'Trailer')).copy()]
print('Container type distribution')
print(P(df, 'unit_type'))

# return probs for dangerous goods
print('Dangerous goods distribution')
p_dg = P(df, 'dangerous_goods')
print(p_dg)

# dangerous goods have 15 places in the yard, reefer containers have 10 places in the yard
# reefer containers have 2/3 of the places in the yard
print('Reefer container distribution')
p_ref = {1-p_dg[1]*2/3, p_dg[1]*2/3}
print(p_ref)

#TODO: create distribution of container heights
#TODO: create distribution of container weights
# Out:
# Container type distribution
# {"40' Container": 0.5315580567616421, 'Wechselbrücke': 0.2558112666082776, "20' Container": 0.1802247358515178, 'Trailer': 0.03240594077856251}
# Dangerous goods distribution
# {0: 0.9901160948884706, 1: 0.009883905111529359}
# Reefer container distribution
# {0.993410729925647, 0.006589270074352906}

# %%
#TODO: Distribution of truck arrival times
#TODO: Distribution of train arrival times
#TODO: Distribution of delay times
#TODO: Duration of stay for trains in yard
#TODO: Average duration of stay for trucks in yard
